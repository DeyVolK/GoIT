# %% [markdown]
# <a href="https://colab.research.google.com/github/DeyVolK/GoIT/blob/main/Cities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

response = requests.get("https://uadata.net/work-positions/cities.json?o=Київ")
data_json = response.json()
df = pd.DataFrame(data_json["data"])
df["at"] = pd.to_datetime(df["at"])
df = df.rename(columns={"at":"Дата", "val":"Вакансії"})
df.set_index('Дата', inplace=True)

# %% [markdown]
# Побудова графіків

# %%
df["Вакансії"].plot()
plt.title("Кількість вакансій по Києву")
plt.xlabel('Дата')
plt.ylabel('Вакансії')
plt.ylim(bottom=0)
plt.show()
df["Вакансії"] = df['Вакансії'].replace(0, np.nan)
df['Вакансії'] = df["Вакансії"].interpolate()
df["Вакансії"].plot()
plt.title("Кількість вакансій по Києву")
plt.xlabel('Дата')
plt.ylabel('Вакансії')
plt.ylim(bottom=0)
plt.show()
df['rolling_mean'] = df['Вакансії'].rolling(window=7).mean()
df["rolling_mean"].plot()
plt.title("Кількість вакансій по Києву")
plt.xlabel('Дата')
plt.ylabel('Вакансії')
plt.ylim(bottom=0)
plt.show()
